# %%
from keras.datasets import cifar10
import sys  
sys.path.insert(0, '../')
from utils import *

# %%
(train_X, train_y), (test_X, test_y) = cifar10.load_data()

# %%
split_and_save_range(train_X_original = train_X, test_X_original = test_X , train_y_original = train_y.flatten(), test_y_original = test_y.flatten(), split_range = range(10,51))
# Out:
# shuffle :10
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :11
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :12
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :13
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :14
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :15
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :16
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :17
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :18
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :19
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :20
# (36000, 3072) (12000, 3072) (12000, 3072) (36000,) (12000,) (12000,)
# shuffle :21
# ...
